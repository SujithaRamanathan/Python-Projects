# %%
import smtplib

# %%
li = ["smartsuji2904@gmail.com","sujitharamanathan1234@gmail.com","ramrishi8754@gmail.com"]

# %%
for i in li:
  s = smtplib.SMTP("smtp.gmail.com",587)
  s.starttls()
  s.login("smartsuji2904@gmail.com", "********")
  msg = "trial run"
  s.sendmail("smartsuji2904@gmail.com",i,msg)
  s.quit()
