# %%
import cv2

# %% [markdown]
# # 1.Creating a cascade classifier **object**

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %% [markdown]
# # **Read our image**

# %%
img = cv2.imread("suji1.jpg")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # **Searching fae co-ordinates of the image**

# %%
faces = face_cascade.detectMultiScale(gray, 1.05, 5)
print(type(faces))
print(faces)
# Out:
# <class 'numpy.ndarray'>
# [[403  60 227 227]]

# %% [markdown]
# # **make rectangle**

# %%
for x,y,w,h in faces:
    img = cv2.rectangle(img, (x,y), (x+w,y+h),(0,255,0),3)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F8651E6C850>
